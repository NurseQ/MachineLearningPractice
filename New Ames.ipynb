# %% [markdown]
# Following along this notebook https://www.kaggle.com/leeclemmer/exploratory-data-analysis-of-housing-in-ames-iowa

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('AmesHousing.csv')

# %%
pd.set_option('max_columns',82)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
# drop the PID column to follow correctly the notebook
df.drop('PID', axis = 1, inplace=True)
df.head()
# Out:
#    Order  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0      1           20        RL         141.0     31770   Pave   NaN
# 1      2           20        RH          80.0     11622   Pave   NaN
# 2      3           20        RL          81.0     14267   Pave   NaN
# 3      4           20        RL          93.0     11160   Pave   NaN
# 4      5           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
print('The dataframe has {} rows and {} columns' .format(df.shape[0],df.shape[1]))
# Out:
# The dataframe has 2930 rows and 81 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
# check how much the houses have sold in df
print('Cheapest house: ${:,.0f}, Most expensive house: ${}'.format(df.SalePrice.min(), df.SalePrice.max()))
print('Average sale price: ${:,.0f}, Median price: ${:,.0f}'.format(df.SalePrice.mean(), df.SalePrice.median()))
df.SalePrice.hist(bins=75,rwidth=.8, figsize=(14,5))
plt.title('Distribution of house prices')
plt.show()
# Out:
# Cheapest house: $12,789, Most expensive house: $755000
# Average sale price: $180,796, Median price: $160,000

# %%
# Check how old the houses are
print('Oldest house: {}, Newest house: {}'.format(df['Year Built'].min(),df['Year Built'].max()))
df['Year Built'].hist( bins = 15, rwidth=.9,figsize=(12, 5))
plt.title('When were the houses built')
plt.show()
# Out:
# Oldest house: 1872, Newest house: 2010

# %%
# group houses according to year and month sold then plot 
df.groupby(['Yr Sold', 'Mo Sold']).Order.count().plot(kind='bar', figsize = (14,4))
plt.title('Year and month sold')
# Out:
# Text(0.5, 1.0, 'Year and month sold')

# %% [markdown]
# The plot suggest a strong seasonal pattern for when the houses sell. May to August is when most of the houses are sold.The data spans around 4 years. Does the time of year have an effect on house price?

# %%
# check the location
df.groupby('Neighborhood').Order.count().sort_values().plot(kind='barh',figsize=(6,8))
plt.title('Where are the houses?')
plt.show()

# %% [markdown]
# Most of the houses sold are in NAmes and a few other neighborhoods. Probably these areas have certain characteristics that make them desirable.

# %%
# Now let us look at how big the houses are
print('Average ground floor area: {:,.0f} ,'.format(df['Gr Liv Area'].mean()))
print('The house with the largest ground floor has: {:,.0f} sqft, the house with the least ground floor area has: {:,.0f} sqft'
      .format(df['Gr Liv Area'].max(),df['Gr Liv Area'].min()))

df['Gr Liv Area'].hist(bins=20, rwidth=.8, figsize=(8,4))
plt.title('Ground floor living area in sqft')
# Out:
# Average ground floor area: 1,500 ,
# The house with the largest ground floor has: 5,642 sqft, the house with the least ground floor area has: 334 sqft
# Text(0.5, 1.0, 'Ground floor living area in sqft')

# %%
# how big are the lots
print('Average size: {:,.0f} sq ft'.format(df['Lot Area'].mean()))
print('Biggest lot: {:,.0f} sq ft, Smallest lot: {:,.0f} sq ft'.format(df['Lot Area'].max(), df['Lot Area'].min()))
df['Lot Area'].hist(bins=60, rwidth=.8, figsize=(8,8))
plt.title('Size of lots')
# Out:
# Average size: 10,148 sq ft
# Biggest lot: 215,245 sq ft, Smallest lot: 1,300 sq ft
# Text(0.5, 1.0, 'Size of lots')

# %% [markdown]
# The plots for the size of the houses show that it is positively skewed. It also shows outliers that are probably correlated to house prices.
#
# Extreme skewness is not desirable as it can result in misleading statistical results.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### In the notebook being followed, the categorical and numerical variables are separated for univariate analysis

# %%
# create a function to separate the numerical from categaorical columns

def group_features():
    
    # numerical features
    num_feat = df.select_dtypes(include = ['int64', 'float64']).columns
    num_feat = num_feat.drop('SalePrice')
    
    # categorical 
    cat_feat = df.select_dtypes(include = ['object']).columns
    return list(num_feat), list(cat_feat)

num_feat, cat_feat = group_features()

# %%
# plot the target variable
plt.figure(figsize=(10,6))
sns.histplot(df.SalePrice, kde=True)

plt.show()

# %%
print('Skew: {:,.3f}, Kurtosis: {:,.3f}'.format(df.SalePrice.skew(), df.SalePrice.kurtosis()))
# Out:
# Skew: 1.744, Kurtosis: 5.119

# %% [markdown]
# If skew value is between -0.5 to 0.5, the distribution is fairly symmetrical, if -1 to -0.5 or 0.5 to 1 it is moderately skewed, but if the values are over -1 or 1 then it is highly skewed

# %%
# create a a grid of distribution plots of all numerical variables

f = pd.melt(df, value_vars = sorted(num_feat))
g = sns.FacetGrid(f, col='variable', col_wrap = 4, sharex = False, sharey=False)
g = g.map(sns.kdeplot, 'value')

# %% [markdown]
# We see several positively skewed columns such as Total Bsmt, Mas Vnr Area, Lot Frontage, Lot Area, 1st Floor Area, 2nd Floor, Bsmt Unf.
#
# There are also some ordinal (Overall Qual, Overall Cond) Sand some count data (TotRms AbvGrd, Kitchen AbvGr, Half Bath).
#
# There are also date or time related variables such Yr Sold, Year Built, Year Remod/Add, Garage Cars.
#
# MS Subclass should be considered as categorical, same as Mo Sold and Yr Sold, for regression purposes, where the author of the notebook explained that the Euclidean distance between the values does not make sense. For Year Built, it is indicative of age of the house.
#
# There are also variables with a large proportion
