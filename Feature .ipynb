# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Covid Predesposition/covid.csv')

# %%
df.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 0               2        2              2        2                    2
# 1               2        2              2        2                   99
# 2               2        1              2        2                   99
# 3               2        2              2        2                   99
# 4               1        2              2        2                   99
#
#    covid_res  icu
# 0          1   97
# 1          1   97
# 2          1    2
# 3          1    2
# 4          1    2
#
# [5 rows x 23 columns]

# %%
df_positive = df[df.covid_res==1]
# only covid positive cases are included

# %%
df_in_positive = df_positive[df_positive.patient_type==2]
# icu patients are icu inpatients

# %%
df_in_positive.icu.value_counts()
# Out:
# 2     62388
# 1      5822
# 99       86
# Name: icu, dtype: int64

# %%
df_in_positive = df_in_positive[df_in_positive.icu!=99]
df_in_positive.reset_index(drop=True)
# Out:
#              id  sex  patient_type  entry_date date_symptoms   date_died  \
# 0        167386    1             2  06-04-2020    01-04-2020  9999-99-99
# 1        0b5948    2             2  17-04-2020    10-04-2020  9999-99-99
# 2        0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020
# 3        1beec8    2             2  16-04-2020    16-04-2020  29-04-2020
# 4      1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99
# ...         ...  ...           ...         ...           ...         ...
# 68205    1a4ec8    2             2  18-06-2020    11-06-2020  9999-99-99
# 68206    0a6ada    2             2  29-03-2020    25-03-2020  9999-99-99
# 68207    16fceb    1             2  29-03-2020    27-03-2020  9999-99-99
# 68208     27424    1             2  10-06-2020    08-06-2020  10-06-2020
# 68209    1b7232    2             2  19-06-2020    09-06-2020  9999-99-99
#
#        intubed  pneumonia  age  pregnancy  ...  inmsupr  hypertension  \
# 0            2          2   54          2  ...        2             2
# 1            2          1   30         97  ...        2             2
# 2            2          2   60          2  ...        2             1
# 3            2          1   47         97  ...        2             2
# 4            2          2   63         97  ...        2             1
# ...        ...        ...  ...        ...  ...      ...           ...
# 68205        2          1   67         97  ...        2             2
# 68206        1          1   65         97  ...        2             1
# 68207        2          1   29          2  ...        2             2
# 68208        2          1   88          2  ...        2             1
# 68209        2          2   70         97  ...        2             2
#
#        other_disease  cardiovascular  obesity  renal_chronic  tobacco  \
# 0                  2               2        1              2        2
# 1                  2               2        2              2        2
# 2                  2               1        2              2        2
# 3                  2               2        2              2        2
# 4                  2               2        2              2        2
# ...              ...             ...      ...            ...      ...
# 68205              2               2        2              2        2
# 68206              2               2        1              2        2
# 68207              2               2        2              2        2
# 68208              2               2        2              2        2
# 68209              2               2        1              2        2
#
#        contact_other_covid  covid_res  icu
# 0                       99          1    2
# 1                       99          1    2
# 2                       99          1    2
# 3                       99          1    1
# 4                       99          1    2
# ...                    ...        ...  ...
# 68205                    1          1    2
# 68206                    2          1    1
# 68207                    2          1    2
# 68208                   99          1    2
# 68209                    2          1    2
#
# [68210 rows x 23 columns]

# %%
df_in_positive = df_in_positive.drop(['id', 'entry_date', 'date_symptoms', 'date_died'],axis='columns')
df_in_positive = df_in_positive.reset_index(drop=True)
# Drop all columns that are not needed for this exercise

# %%
notagecol = ['patient_type','pregnancy','diabetes','copd', 'asthma', 'inmsupr', 'hypertension', 'other_disease','cardiovascular','obesity','renal_chronic','tobacco','intubed', 'contact_other_covid','covid_res']
# remove all 98's in selected columns
for col in notagecol:
    df_in_positive = df_in_positive[df_in_positive[col]!=98]
    
df_in_positive.reset_index(drop=True)
# Out:
#        sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0        1             2        2          2   54          2         2     2
# 1        2             2        2          1   30         97         2     2
# 2        1             2        2          2   60          2         1     2
# 3        2             2        2          1   47         97         1     2
# 4        2             2        2          2   63         97         2     2
# ...    ...           ...      ...        ...  ...        ...       ...   ...
# 67231    2             2        2          1   67         97         2     2
# 67232    2             2        1          1   65         97         1     2
# 67233    1             2        2          1   29          2         2     2
# 67234    1             2        2          1   88          2         1     2
# 67235    2             2        2          2   70         97         2     2
#
#        asthma  inmsupr  hypertension  other_disease  cardiovascular  obesity  \
# 0           2        2             2              2               2        1
# 1           2        2             2              2               2        2
# 2           2        2             1              2               1        2
# 3           2        2             2              2               2        2
# 4           2        2             1              2               2        2
# ...       ...      ...           ...            ...             ...      ...
# 67231       2        2             2              2               2        2
# 67232       2        2             1              2               2        1
# 67233       2        2             2              2               2        2
# 67234       2        2             1              2               2        2
# 67235       2        2             2              2               2        1
#
#        renal_chronic  tobacco  contact_other_covid  covid_res  icu
# 0                  2        2                   99          1    2
# 1                  2        2                   99          1    2
# 2                  2        2                   99          1    2
# 3                  2        2                   99          1    1
# 4                  2        2                   99          1    2
# ...              ...      ...                  ...        ...  ...
# 67231              2        2                    1          1    2
# 67232              2        2                    2          1    1
# 67233              2        2                    2          1    2
# 67234              2        2                   99          1    2
# 67235              2        2                    2          1    2
#
# [67236 rows x 19 columns]

# %%
# replace age with an age range
df_in_positive['age'] = pd.cut(df_in_positive['age'], bins=[0,20,40,60,150], labels=[1,2,3,4])

# %%
df_in_positive['age'].value_counts()
# Out:
# 3    29880
# 4    25752
# 2    10489
# 1      847
# Name: age, dtype: int64

# %%
df_in_positive
# Out:
#        sex  patient_type  intubed  pneumonia age  pregnancy  diabetes  copd  \
# 0        1             2        2          2   3          2         2     2
# 1        2             2        2          1   2         97         2     2
# 2        1             2        2          2   3          2         1     2
# 3        2             2        2          1   3         97         1     2
# 4        2             2        2          2   4         97         2     2
# ...    ...           ...      ...        ...  ..        ...       ...   ...
# 68205    2             2        2          1   4         97         2     2
# 68206    2             2        1          1   4         97         1     2
# 68207    1             2        2          1   2          2         2     2
# 68208    1             2        2          1   4          2         1     2
# 68209    2             2        2          2   4         97         2     2
#
#        asthma  inmsupr  hypertension  other_disease  cardiovascular  obesity  \
# 0           2        2             2              2               2        1
# 1           2        2             2              2               2        2
# 2           2        2             1              2               1        2
# 3           2        2             2              2               2        2
# 4           2        2             1              2               2        2
# ...       ...      ...           ...            ...             ...      ...
# 68205       2        2             2              2               2        2
# 68206       2        2             1              2               2        1
# 68207       2        2             2              2               2        2
# 68208       2        2             1              2               2        2
# 68209       2        2             2              2               2        1
#
#        renal_chronic  tobacco  contact_other_covid  covid_res  icu
# 0                  2        2                   99          1    2
# 1                  2        2                   99          1    2
# 2                  2        2                   99          1    2
# 3                  2        2                   99          1    1
# 4                  2        2                   99          1    2
# ...              ...      ...                  ...        ...  ...
# 68205              2        2                    1          1    2
# 68206              2        2                    2          1    1
# 68207              2        2                    2          1    2
# 68208              2        2                   99          1    2
# 68209              2        2                    2          1    2
#
# [67236 rows x 19 columns]

# %% [markdown]
# ## Filter Methods

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_in_positive.drop(labels=['icu'],axis=1),df_in_positive['icu'],
    test_size=0.33, random_state=42)

X_train.shape,X_test.shape
# Out:
# ((45048, 18), (22188, 18))

# %% [markdown]
# ### Variance Threshold
# Remove features that doesn't meet a certain threshold, by default, it removes all zero-variance variables, features that have the same value in all samples.

# %%
sel = VarianceThreshold(threshold=0)
sel.fit(X_train) # fit finds the features with zero variance
# Out:
# VarianceThreshold(threshold=0)

# %%
# get_support is a boolean vector that indicates which features are retained
sum(sel.get_support())
# Out:
# 16

# %%
# print the number of constant features
constant = X_train.columns[~sel.get_support()]
len(constant)
# Out:
# 2

# %%
constant
# Out:
# Index(['patient_type', 'covid_res'], dtype='object')

# %%
# this is true because we chose only inpatients who are covid positive.
for col in constant:
    print(col, X_train[col].unique())
# Out:
# patient_type [2]
# covid_res [1]

# %%
# We can just drop the 2 variables but this will be laborious if there are numerous variables.
# capture the non-constant features names

feat_names = X_train.columns[sel.get_support()]
test_names = X_test.columns[sel.get_support()]

# %%
# use transform() to reduce the training and testing sets
X_train = sel.transform(X_train)
X_test = sel.transform(X_test)

X_train.shape, X_test.shape
# Out:
# ((45048, 16), (22188, 16))

# %%
X_test
# Out:
# array([[ 2,  2,  1, ...,  2,  2,  1],
#        [ 2,  2,  1, ...,  1,  2, 99],
#        [ 2,  2,  2, ...,  2,  2, 99],
#        ...,
#        [ 1,  2,  1, ...,  2,  2,  2],
#        [ 1,  1,  1, ...,  2,  2,  1],
#        [ 2,  2,  2, ...,  2,  2, 99]], dtype=int64)

# %%
# VarianceThreshold returns a numpy array without feature names so the dataframe need to be reconstituted

X_train = pd.DataFrame(X_train, columns=feat_names)
X_test = pd.DataFrame(X_test, columns=feat_names)

X_test.head()
# Out:
#    sex  intubed  pneumonia  age  pregnancy  diabetes  copd  asthma  inmsupr  \
# 0    2        2          1    3         97         1     2       2        2
# 1    2        2          1    4         97         1     1       2        2
# 2    2        2          2    3         97         2     2       2        2
# 3    2        2          1    4         97         2     2       2        2
# 4    2        2          2    4         97         1     2       2        2
#
#    hypertension  other_disease  cardiovascular  obesity  renal_chronic  \
# 0             2              2               2        2              2
# 1             1              2               1        2              1
# 2             2              2               2        2              2
# 3             2              2               2        2              2
# 4             1              2               2        1              2
#
#    tobacco  contact_other_covid
# 0        2                    1
# 1        2                   99
# 2        2                   99
# 3        2                    2
# 4        2                    2

# %% [markdown]
# ### Categorical Variables
# VarianceThreshold and standard deviation can only be used with numerical variables, so looking for unique values can be used for both categorical and numerical variables

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_in_positive.drop(labels=['icu'],axis=1),df_in_positive['icu'],
    test_size=0.33, random_state=42)

X_train.shape,X_test.shape
# Out:
# ((45048, 18), (22188, 18))

# %%
constant_variables = [feat for feat in X_train.columns if X_train[feat].nunique() ==1]

len(constant_variables)
# Out:
# 2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_in_positive.drop(labels=['icu'],axis=1),df_in_positive['icu'],
    test_size=0.33, random_state=42)

X_train.shape,X_test.shape
# Out:
# ((45048, 18), (22188, 18))

# %%
# drop constant variables
X_train.drop(labels=constant_variables, axis=1, inplace=True)
X_test.drop(labels=constant_variables, axis=1, inplace=True)

X_train.shape, X_test.shape
# Out:
# ((45048, 16), (22188, 16))

# %% [markdown]
# ### Quasi-Constant Features
# This feature show the same value for a great majority of observations. They provide little, if any information.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_in_positive.drop(labels=['icu'],axis=1),df_in_positive['icu'],
    test_size=0.33, random_state=42)

X_train.shape,X_test.shape
# Out:
# ((45048, 18), (22188, 18))

# %%
sel = VarianceThreshold(threshold=0.01)# variance is more than zero
sel.fit(X_train)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
sum(sel.get_support())
# Out:
# 16

# %% [markdown]
# ### Duplicated features
# check if each column has a duplicate

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_in_positive.drop(labels=['icu'],axis=1),df_in_positive['icu'],
    test_size=0.33, random_state=42)

X_train.shape,X_test.shape
# Out:
# ((45048, 18), (22188, 18))

# %%
# check for duplicated pairs

# create an empty dict to store groups of duplicates

duplicated_feat_pairs = {}

# create an empty list to collect features found to be duplicates

dup_feat = []

# %%
# iterate over every feature in our dataset:

for i in range(0, len (X_train.columns)):
    
    feat_1 = X_train.columns[i]
    
    # we check if the feature is already identified
    if feat_1 not in dup_feat:
        
        duplicated_feat_pairs[feat_1] = []
        
        # iterate over the reamining features of the dataset:
        
        for feat_2 in X_train.columns[i + 1:]:
            
            # check if this second feature is identical to the first one
            if X_train[feat_1].equals(X_train[feat_2]):
                
                #if it is identical, append it to the list in the dictionary
                duplicated_feat_pairs[feat_1].append(feat_2)
                
                # append it to our monitor list
                dup_feat.append(feat_2)

# %%
len(dup_feat)
# Out:
# 0
